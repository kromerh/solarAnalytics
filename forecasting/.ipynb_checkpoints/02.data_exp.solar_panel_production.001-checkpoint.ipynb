# %% [markdown]
# # STEP 02: Data exploration, Solar panel production Version 001
#
# In this notebook, the data exploration of the **solar panel production** is covered. There are three data sources that are being explored:
#
# 1. Weather: Information on temperature, cloud coverage, precipitation, etc at the location using the DarkSkyAPI
# 2. Sun position: Information on the position of the sun in the sky at the location using pysolar.solar
# 3. Solar panel production: Information on the amount of energy produced by the solar panels at the location

# %%
import datetime
import numpy as np
import pandas as pd
import requests
import re
import json
import os
from dateutil import tz
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %% [markdown]
# # Load data

# %%
path_to_files = './data/production/'
data = pd.read_csv(f'{path_to_files}/solar_production.data', index_col=0) # make it .data so that it is not csv
data['Time'] = pd.to_datetime(data['Time'])
data = data.set_index('Time')
data.head()
# Out:
#                      Production
# Time
# 2017-10-12 00:00:00         0.0
# 2017-10-12 00:15:00         0.0
# 2017-10-12 00:30:00         0.0
# 2017-10-12 00:45:00         0.0
# 2017-10-12 01:00:00         0.0

# %% [markdown]
# # Describe data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59904 entries, 0 to 95
# Data columns (total 2 columns):
# Production    59904 non-null float64
# Time          59904 non-null object
# dtypes: float64(1), object(1)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#          Production
# count  59904.000000
# mean     944.207911
# std     1637.985607
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%     1191.083350
# max     6963.666500

# %% [markdown]
# Production is in Watt.

# %% [markdown]
# # Visualize

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(data['Production'])
plt.title('Production, full period')
plt.show()
fig = plt.figure(figsize=(10,6))
plt.plot(data.loc['2017-11-01':'2017-11-02','Production'])
plt.title('Production, 48 hours')
plt.show()

# %% [markdown]
# Check that it is 96 entries per day, which is every 15 minutes for 24 hours

# %%
data_agg = data.reset_index()
data_agg['Day'] = data_agg['Time'].map(lambda x: f'{x.year}-{x.month}-{x.day}')
data_agg.groupby('Day').agg(['count']).min()
# Out:
# Time        count    96
# Production  count    96
# dtype: int64

# %%
data_agg.groupby('Day').agg(['count']).max()
# Out:
# Time        count    96
# Production  count    96
# dtype: int64

# %% [markdown]
# # Aggregate by day

# %%
# production data
path_to_files = './data/production/'
data_prod = pd.read_csv(f'{path_to_files}/solar_production.data', index_col=0) # make it .data so that it is not csv
data_prod['Time'] = pd.to_datetime(data_prod['Time'])
data_prod = data_prod.set_index('Time')

data_prod['Day'] = data_prod.index.map(lambda x: f'{x.year}-{x.month}-{x.day}')
data_prod = data_prod.groupby('Day')['Production'].agg(['sum'])
data_prod.columns = ['Production_sum']

data_prod =  data_prod.reset_index()
data_prod['Day'] = pd.to_datetime(data_prod['Day'])
data_prod = data_prod.sort_values(by=['Day'])
data_prod = data_prod.set_index('Day')
data_prod.head()
# Out:
#             Production_sum
# Day
# 2017-10-12      11629.3334
# 2017-10-13     118196.0001
# 2017-10-14     114615.3339
# 2017-10-15     113638.9996
# 2017-10-16     109484.3342

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(data_prod['Production_sum'])
plt.title('Production_sum, full period')
plt.show()
fig = plt.figure(figsize=(10,6))
plt.plot(data_prod.loc['2017-11-01':'2017-11-10','Production_sum'])
plt.title('Production_sum, 48 hours')
plt.show()

# %%
plt.boxplot(data_prod['Production_sum'])
plt.show()
plt.hist(data_prod['Production_sum'], bins=3)
plt.show()
data_prod.describe()
# Out:
#        Production_sum
# count      624.000000
# mean     90643.959410
# std      62618.881326
# min          0.000000
# 25%      31844.416550
# 50%      83353.666650
# 75%     139221.749850
# max     224522.000100
