# %%
# do not upload this cell! 
API_PATH = '/Users/hkromer/01_Projects/10.SolarAnlage/01.Analytics/solarAnalytics/2020-04-16.solarAnalytics/01.Original_data/DarkSky/DarkSkyAPI.pw'
LOCATION_PATH = '/Users/hkromer/01_Projects/10.SolarAnlage/01.Analytics/solarAnalytics/2020-04-16.solarAnalytics/01.Original_data/location.pw'

# %% [markdown]
# # ETL of DarkSky Data
#
# In this project, the extraction of weather data with python3 using the DarkSky API (https://darksky.net/dev) is covered. This data is to be used in forecasting of photovoltaic energy production. Signup on DarkSky is free, as long as one stays below 1000 API calls per 24 hours.
#
# The way this pipeline will be laid out is that the DarkSky API is called and returns hourly, historical data for each day that is requested. The response from the API in the form of json files will be stored locally and then be processed into one big csv file with all the data from the API. For the final purpose of this dataset, the forecasting of photovoltaic energy production, not all of the data in DarkSky must be relevant.

# %% [markdown]
# ## Import

# %%
import datetime
import pandas as pd
import requests
import re
import json
import os
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4b3168635d0d> in <module>
#       1 import datetime
#       2 import pandas as pd
# ----> 3 import requests
#       4 import re
#       5 import json
#
# ModuleNotFoundError: No module named 'requests'

# %%
location = [item.strip() for item in open(LOCATION_PATH, 'r').readlines()[0].strip().split()]
DarkSkyAPI = open(API_PATH, 'r').readlines()[0].strip()

date_str = '2018-08-11'

ds = DarkSkyETL(LOCATION, DarkSkyAPI,'../01.Original_data/')

a = ds.call_API(date_str, silent=False)

# %%
start_date = '2017-10-01'
end_date = '2020-01-13'
save_path = '../01.Original_data/DarkSky/'
silent = False

ds = DarkSkyETL(LOCATION, DarkSkyAPI, save_path)

ds.get_date_range(start_date, end_date, silent)
# Out:
# 2017-10-01
# Loaded 24 datapoints for 2017-10-01
# 2017-10-02
# Loaded 24 datapoints for 2017-10-02
# 2017-10-03
# Loaded 24 datapoints for 2017-10-03
# 2017-10-04
# Loaded 24 datapoints for 2017-10-04
# 2017-10-05
# Loaded 24 datapoints for 2017-10-05
# 2017-10-06
# Loaded 24 datapoints for 2017-10-06
# 2017-10-07
# Loaded 24 datapoints for 2017-10-07
# 2017-10-08
# Loaded 24 datapoints for 2017-10-08
# 2017-10-09
# Loaded 24 datapoints for 2017-10-09
# 2017-10-10
# Loaded 24 datapoints for 2017-10-10
# 2017-10-11
# Loaded 24 datapoints for 2017-10-11
# 2017-10-12
# Loaded 24 datapoints for 2017-10-12
# 2017-10-13
# Loaded 24 datapoints for 2017-10-13
# 2017-10-14
# Loaded 24 datapoints for 2017-10-14
# 2017-10-15
# Loaded 24 datapoints for 2017-10-15
# 2017-10-16
# Loaded 24 datapoints for 2017-10-16
# 2017-10-17
# Loaded 24 datapoints for 2017-10-17
# 2017-10-18
# Loaded 24 datapoints for 2017-10-18
# 2017-10-19
# Loaded 24 datapoints for 2017-10-19
# 2017-10-20
# Loaded 24 datapoints for 2017-10-20
# 2017-10-21
# Loaded 24 datapoints for 2017-10-21
# 2017-10-22
# Loaded 24 datapoints for 2017-10-22
# 2017-10-23
# Loaded 24 datapoints for 2017-10-23
# 2017-10-24
# Loaded 24 datapoints for 2017-10-24
# 2017-10-25
# Loaded 24 datapoints for 2017-10-25
# 2017-10-26
# Loaded 24 datapoints for 2017-10-26
# 2017-10-27
# Loaded 24 datapoints for 2017-10-27
# 2017-10-28
# Loaded 24 datapoints for 2017-10-28
# 2017-10-29
# Loaded 25 datapoints for 2017-10-29
# 2017-10-30
# Loaded 24 datapoints for 2017-10-30
# 2017-10-31
# Loaded 24 datapoints for 2017-10-31
# 2017-11-01
# Loaded 24 datapoints for 2017-11-01
# 2017-11-02
# Loaded 24 datapoints for 2017-11-02
# 2017-11-03
# Loaded 24 datapoints for 2017-11-03
# 2017-11-04
# Loaded 24 datapoints for 2017-11-04
# 2017-11-05
# Loaded 24 datapoints for 2017-11-05
# 2017-11-06
# Loaded 24 datapoints for 2017-11-06
# 2017-11-07
# Loaded 24 datapoints for 2017-11-07
# 2017-11-08
# Loaded 24 datapoints for 2017-11-08
# 2017-11-09
# Loaded 24 datapoints for 2017-11-09
# 2017-11-10
# Loaded 24 datapoints for 2017-11-10
# 2017-11-11
# Loaded 24 datapoints for 2017-11-11
# 2017-11-12
# Loaded 24 datapoints for 2017-11-12
# 2017-11-13
# Loaded 24 datapoints for 2017-11-13
# 2017-11-14
# Loaded 24 datapoints for 2017-11-14
# 2017-11-15
# Loaded 24 datapoints for 2017-11-15
# 2017-11-16
# Loaded 24 datapoints for 2017-11-16
# 2017-11-17
# Loaded 24 datapoints for 2017-11-17
# 2017-11-18
# Loaded 24 datapoints for 2017-11-18
# 2017-11-19
# Loaded 24 datapoints for 2017-11-19
# 2017-11-20
# Loaded 24 datapoints for 2017-11-20
# 2017-11-21
# Loaded 24 datapoints for 2017-11-21
# 2017-11-22
# Loaded 24 datapoints for 2017-11-22
# 2017-11-23
# Loaded 24 datapoints for 2017-11-23
# 2017-11-24
# Loaded 24 datapoints for 2017-11-24
# 2017-11-25
# Loaded 24 datapoints for 2017-11-25
# 2017-11-26
# Loaded 24 datapoints for 2017-11-26
# 2017-11-27
# Loaded 24 datapoints for 2017-11-27
# 2017-11-28
# Loaded 24 datapoints for 2017-11-28
# 2017-11-29
# Loaded 24 datapoints for 2017-11-29
# 2017-11-30
# Loaded 24 datapoints for 2017-11-30
# 2017-12-01
# Loaded 24 datapoints for 2017-12-01
# 2017-12-02
# Loaded 24 datapoints for 2017-12-02
# 2017-12-03
# Loaded 24 datapoints for 2017-12-03
# 2017-12-04
# Loaded 24 datapoints for 2017-12-04
# 2017-12-05
# Loaded 24 datapoints for 2017-12-05
# 2017-12-06
# Loaded 24 datapoints for 2017-12-06
# 2017-12-07
# Loaded 24 datapoints for 2017-12-07
# 2017-12-08
# Loaded 24 datapoints for 2017-12-08
# 2017-12-09
# Loaded 24 datapoints for 2017-12-09
# 2017-12-10
# Loaded 24 datapoints for 2017-12-10
# 2017-12-11
# Loaded 24 datapoints for 2017-12-11
# 2017-12-12
# Loaded 24 datapoints for 2017-12-12
# 2017-12-13
# Loaded 24 datapoints for 2017-12-13
# 2017-12-14
# Loaded 24 datapoints for 2017-12-14
# 2017-12-15
# Loaded 24 datapoints for 2017-12-15
# 2017-12-16
# Loaded 24 datapoints for 2017-12-16
# 2017-12-17
# Loaded 24 datapoints for 2017-12-17
# 2017-12-18
# Loaded 24 datapoints for 2017-12-18
# 2017-12-19
# Loaded 24 datapoints for 2017-12-19
# 2017-12-20
# Loaded 24 datapoints for 2017-12-20
# 2017-12-21
# Loaded 24 datapoints for 2017-12-21
# 2017-12-22
# Loaded 24 datapoints for 2017-12-22
# 2017-12-23
# Loaded 24 datapoints for 2017-12-23
# 2017-12-24
# Loaded 24 datapoints for 2017-12-24
# 2017-12-25
# Loaded 24 datapoints for 2017-12-25
# 2017-12-26
# Loaded 24 datapoints for 2017-12-26
# 2017-12-27
# Loaded 24 datapoints for 2017-12-27
# 2017-12-28
# Loaded 24 datapoints for 2017-12-28
# 2017-12-29
# Loaded 24 datapoints for 2017-12-29
# 2017-12-30
# Loaded 24 datapoints for 2017-12-30
# 2017-12-31
# Loaded 24 datapoints for 2017-12-31
# 2018-01-01
# Loaded 24 datapoints for 2018-01-01
# 2018-01-02
# Loaded 24 datapoints for 2018-01-02
# 2018-01-03
# Loaded 24 datapoints for 2018-01-03
# 2018-01-04
# Loaded 24 datapoints for 2018-01-04
# 2018-01-05
# Loaded 24 datapoints for 2018-01-05
# 2018-01-06
# Loaded 24 datapoints for 2018-01-06
# 2018-01-07
# Loaded 24 datapoints for 2018-01-07
# 2018-01-08
# Loaded 24 datapoints for 2018-01-08
# 2018-01-09
# Loaded 24 datapoints for 2018-01-09
# 2018-01-10
# Loaded 24 datapoints for 2018-01-10
# 2018-01-11
# Loaded 24 datapoints for 2018-01-11
# 2018-01-12
# Loaded 24 datapoints for 2018-01-12
# 2018-01-13
# Loaded 24 datapoints for 2018-01-13
# 2018-01-14
# Loaded 24 datapoints for 2018-01-14
# 2018-01-15
# Loaded 24 datapoints for 2018-01-15
# 2018-01-16
# Loaded 24 datapoints for 2018-01-16
# 2018-01-17
# Loaded 24 datapoints for 2018-01-17
# 2018-01-18
# Loaded 24 datapoints for 2018-01-18
# 2018-01-19
# Loaded 24 datapoints for 2018-01-19
# 2018-01-20
# Loaded 24 datapoints for 2018-01-20
# 2018-01-21
# Loaded 24 datapoints for 2018-01-21
# 2018-01-22
# Loaded 24 datapoints for 2018-01-22
# 2018-01-23
# Loaded 24 datapoints for 2018-01-23
# 2018-01-24
# Loaded 24 datapoints for 2018-01-24
# 2018-01-25
# Loaded 24 datapoints for 2018-01-25
# 2018-01-26
# Loaded 24 datapoints for 2018-01-26
# 2018-01-27
# Loaded 24 datapoints for 2018-01-27
# 2018-01-28
# Loaded 24 datapoints for 2018-01-28
# 2018-01-29
# Loaded 24 datapoints for 2018-01-29
# 2018-01-30
# Loaded 24 datapoints for 2018-01-30
# 2018-01-31
# Loaded 24 datapoints for 2018-01-31
# 2018-02-01
# Loaded 24 datapoints for 2018-02-01
# 2018-02-02
# Loaded 24 datapoints for 2018-02-02
# 2018-02-03
# Loaded 24 datapoints for 2018-02-03
# 2018-02-04
# Loaded 24 datapoints for 2018-02-04
# 2018-02-05
# Loaded 24 datapoints for 2018-02-05
# 2018-02-06
# Loaded 24 datapoints for 2018-02-06
# 2018-02-07
# Loaded 24 datapoints for 2018-02-07
# 2018-02-08
# Loaded 24 datapoints for 2018-02-08
# 2018-02-09
# Loaded 24 datapoints for 2018-02-09
# 2018-02-10
# Loaded 24 datapoints for 2018-02-10
# 2018-02-11
# Loaded 24 datapoints for 2018-02-11
# 2018-02-12
# Loaded 24 datapoints for 2018-02-12
# 2018-02-13
# Loaded 24 datapoints for 2018-02-13
# 2018-02-14
# Loaded 24 datapoints for 2018-02-14
# 2018-02-15
# Loaded 24 datapoints for 2018-02-15
# 2018-02-16
# Loaded 24 datapoints for 2018-02-16
# 2018-02-17
# Loaded 24 datapoints for 2018-02-17
# 2018-02-18
# Loaded 24 datapoints for 2018-02-18
# 2018-02-19
# Loaded 24 datapoints for 2018-02-19
# 2018-02-20
# Loaded 24 datapoints for 2018-02-20
# 2018-02-21
# Loaded 24 datapoints for 2018-02-21
# 2018-02-22
# Loaded 24 datapoints for 2018-02-22
# 2018-02-23
# Loaded 24 datapoints for 2018-02-23
# 2018-02-24
# Loaded 24 datapoints for 2018-02-24
# 2018-02-25
# Loaded 24 datapoints for 2018-02-25
# 2018-02-26
# Loaded 24 datapoints for 2018-02-26
# 2018-02-27
# Loaded 24 datapoints for 2018-02-27
# 2018-02-28
# Loaded 24 datapoints for 2018-02-28
# 2018-03-01
# Loaded 24 datapoints for 2018-03-01
# 2018-03-02
# Loaded 24 datapoints for 2018-03-02
# 2018-03-03
# Loaded 24 datapoints for 2018-03-03
# 2018-03-04
# Loaded 24 datapoints for 2018-03-04
# 2018-03-05
# Loaded 24 datapoints for 2018-03-05
# 2018-03-06
# Loaded 24 datapoints for 2018-03-06
# 2018-03-07
# Loaded 24 datapoints for 2018-03-07
# 2018-03-08
# Loaded 24 datapoints for 2018-03-08
# 2018-03-09
# Loaded 24 datapoints for 2018-03-09
# 2018-03-10
# Loaded 24 datapoints for 2018-03-10
# 2018-03-11
# Loaded 24 datapoints for 2018-03-11
# 2018-03-12
# Loaded 24 datapoints for 2018-03-12
# 2018-03-13
# Loaded 24 datapoints for 2018-03-13
# 2018-03-14
# Loaded 24 datapoints for 2018-03-14
# 2018-03-15
# Loaded 24 datapoints for 2018-03-15
# 2018-03-16
# Loaded 24 datapoints for 2018-03-16
# 2018-03-17
# Loaded 24 datapoints for 2018-03-17
# 2018-03-18
# Loaded 24 datapoints for 2018-03-18
# 2018-03-19
# Loaded 24 datapoints for 2018-03-19
# 2018-03-20
# Loaded 24 datapoints for 2018-03-20
# 2018-03-21
# Loaded 24 datapoints for 2018-03-21
# 2018-03-22
# Loaded 24 datapoints for 2018-03-22
# 2018-03-23
# Loaded 24 datapoints for 2018-03-23
# 2018-03-24
# Loaded 24 datapoints for 2018-03-24
# 2018-03-25
# Loaded 23 datapoints for 2018-03-25
# 2018-03-26
# Loaded 24 datapoints for 2018-03-26
# 2018-03-27
# Loaded 24 datapoints for 2018-03-27
# 2018-03-28
# Loaded 24 datapoints for 2018-03-28
# 2018-03-29
# Loaded 24 datapoints for 2018-03-29
# 2018-03-30
# Loaded 24 datapoints for 2018-03-30
# 2018-03-31
# Loaded 24 datapoints for 2018-03-31
# 2018-04-01
# Loaded 24 datapoints for 2018-04-01
# 2018-04-02
# Loaded 24 datapoints for 2018-04-02
# 2018-04-03
# Loaded 24 datapoints for 2018-04-03
# 2018-04-04
# Loaded 24 datapoints for 2018-04-04
# 2018-04-05
# Loaded 24 datapoints for 2018-04-05
# 2018-04-06
# Loaded 24 datapoints for 2018-04-06
# 2018-04-07
# Loaded 24 datapoints for 2018-04-07
# 2018-04-08
# Loaded 24 datapoints for 2018-04-08
# 2018-04-09
# Loaded 24 datapoints for 2018-04-09
# 2018-04-10
# Loaded 24 datapoints for 2018-04-10
# 2018-04-11
# Loaded 24 datapoints for 2018-04-11
# 2018-04-12
# Loaded 24 datapoints for 2018-04-12
# 2018-04-13
# Loaded 24 datapoints for 2018-04-13
# 2018-04-14
# Loaded 24 datapoints for 2018-04-14
# 2018-04-15
# Loaded 24 datapoints for 2018-04-15
# 2018-04-16
# Loaded 24 datapoints for 2018-04-16
# 2018-04-17
# Loaded 24 datapoints for 2018-04-17
# 2018-04-18
# Loaded 24 datapoints for 2018-04-18
# 2018-04-19
# Loaded 24 datapoints for 2018-04-19
# 2018-04-20
# Loaded 24 datapoints for 2018-04-20
# 2018-04-21
# Loaded 24 datapoints for 2018-04-21
# 2018-04-22
# Loaded 24 datapoints for 2018-04-22
# 2018-04-23
# Loaded 24 datapoints for 2018-04-23
# 2018-04-24
# Loaded 24 datapoints for 2018-04-24
# 2018-04-25
# Loaded 24 datapoints for 2018-04-25
# 2018-04-26
# Loaded 24 datapoints for 2018-04-26
# 2018-04-27
# Loaded 24 datapoints for 2018-04-27
# 2018-04-28
# Loaded 24 datapoints for 2018-04-28
# 2018-04-29
# Loaded 24 datapoints for 2018-04-29
# 2018-04-30
# Loaded 24 datapoints for 2018-04-30
# 2018-05-01
# Loaded 24 datapoints for 2018-05-01
# 2018-05-02
# Loaded 24 datapoints for 2018-05-02
# 2018-05-03
# Loaded 24 datapoints for 2018-05-03
# 2018-05-04
# Loaded 24 datapoints for 2018-05-04
# 2018-05-05
# Loaded 24 datapoints for 2018-05-05
# 2018-05-06
# Loaded 24 datapoints for 2018-05-06
# 2018-05-07
# Loaded 24 datapoints for 2018-05-07
# 2018-05-08
# Loaded 24 datapoints for 2018-05-08
# 2018-05-09
# Loaded 24 datapoints for 2018-05-09
# 2018-05-10
# Loaded 24 datapoints for 2018-05-10
# 2018-05-11
# Loaded 24 datapoints for 2018-05-11
# 2018-05-12
# Loaded 24 datapoints for 2018-05-12
# 2018-05-13
# Loaded 24 datapoints for 2018-05-13
# 2018-05-14
# Loaded 24 datapoints for 2018-05-14
# 2018-05-15
# Loaded 24 datapoints for 2018-05-15
# 2018-05-16
# Loaded 24 datapoints for 2018-05-16
# 2018-05-17
# Loaded 24 datapoints for 2018-05-17
# 2018-05-18
# Loaded 24 datapoints for 2018-05-18
# 2018-05-19
# Loaded 19 datapoints for 2018-05-19
# 2018-05-20
# Loaded 10 datapoints for 2018-05-20
# 2018-05-21
# Loaded 8 datapoints for 2018-05-21
# 2018-05-22
# Loaded 13 datapoints for 2018-05-22
# 2018-05-23
# Loaded 14 datapoints for 2018-05-23
# 2018-05-24
# Loaded 16 datapoints for 2018-05-24
# 2018-05-25
# Loaded 15 datapoints for 2018-05-25
# 2018-05-26
# Loaded 10 datapoints for 2018-05-26
# 2018-05-27
# Loaded 10 datapoints for 2018-05-27
# 2018-05-28
# Loaded 16 datapoints for 2018-05-28
# 2018-05-29
# Loaded 13 datapoints for 2018-05-29
# 2018-05-30
# Loaded 14 datapoints for 2018-05-30
# 2018-05-31
# Loaded 10 datapoints for 2018-05-31
# 2018-06-01
# Loaded 13 datapoints for 2018-06-01
# 2018-06-02
# Loaded 11 datapoints for 2018-06-02
# 2018-06-03
# Loaded 12 datapoints for 2018-06-03
# 2018-06-04
# Loaded 13 datapoints for 2018-06-04
# 2018-06-05
# Loaded 13 datapoints for 2018-06-05
# 2018-06-06
# Loaded 15 datapoints for 2018-06-06
# 2018-06-07
# Loaded 13 datapoints for 2018-06-07
# 2018-06-08
# Loaded 14 datapoints for 2018-06-08
# 2018-06-09
# Loaded 10 datapoints for 2018-06-09
# 2018-06-10
# Loaded 8 datapoints for 2018-06-10
# 2018-06-11
# Loaded 14 datapoints for 2018-06-11
# 2018-06-12
# Loaded 15 datapoints for 2018-06-12
# 2018-06-13
# Loaded 13 datapoints for 2018-06-13
# 2018-06-14
# Loaded 13 datapoints for 2018-06-14
# 2018-06-15
# Loaded 13 datapoints for 2018-06-15
# 2018-06-16
# Loaded 4 datapoints for 2018-06-16
# 2018-06-17
# Loaded 10 datapoints for 2018-06-17
# 2018-06-18
# Loaded 13 datapoints for 2018-06-18
# 2018-06-19
# Loaded 13 datapoints for 2018-06-19
# 2018-06-20
# Loaded 13 datapoints for 2018-06-20
# 2018-06-21
# Loaded 12 datapoints for 2018-06-21
# 2018-06-22
# Loaded 13 datapoints for 2018-06-22
# 2018-06-23
# Loaded 12 datapoints for 2018-06-23
# 2018-06-24
# Loaded 10 datapoints for 2018-06-24
# 2018-06-25
# Loaded 16 datapoints for 2018-06-25
# 2018-06-26
# Loaded 15 datapoints for 2018-06-26
# 2018-06-27
# Loaded 13 datapoints for 2018-06-27
# 2018-06-28
# Loaded 13 datapoints for 2018-06-28
# 2018-06-29
# Loaded 13 datapoints for 2018-06-29
# 2018-06-30
# Loaded 12 datapoints for 2018-06-30
# 2018-07-01
# Loaded 10 datapoints for 2018-07-01
# 2018-07-02
# Loaded 13 datapoints for 2018-07-02
# 2018-07-03
# Loaded 14 datapoints for 2018-07-03
# 2018-07-04
# Loaded 14 datapoints for 2018-07-04
# 2018-07-05
# Loaded 15 datapoints for 2018-07-05
# 2018-07-06
# Loaded 15 datapoints for 2018-07-06
# 2018-07-07
# Loaded 3 datapoints for 2018-07-07
# 2018-07-08
# Loaded 3 datapoints for 2018-07-08
# 2018-07-09
# Loaded 14 datapoints for 2018-07-09
# 2018-07-10
# Loaded 14 datapoints for 2018-07-10
# 2018-07-11
# Loaded 14 datapoints for 2018-07-11
# 2018-07-12
# Loaded 14 datapoints for 2018-07-12
# 2018-07-13
# Loaded 13 datapoints for 2018-07-13
# 2018-07-14
# Loaded 15 datapoints for 2018-07-14
# 2018-07-15
# Loaded 11 datapoints for 2018-07-15
# 2018-07-16
# Loaded 13 datapoints for 2018-07-16
# 2018-07-17
# Loaded 13 datapoints for 2018-07-17
# 2018-07-18
# Loaded 12 datapoints for 2018-07-18
# 2018-07-19
# Loaded 13 datapoints for 2018-07-19
# 2018-07-20
# Loaded 12 datapoints for 2018-07-20
# 2018-07-21
# Loaded 4 datapoints for 2018-07-21
# 2018-07-22
# Loaded 4 datapoints for 2018-07-22
# 2018-07-23
# Loaded 13 datapoints for 2018-07-23
# 2018-07-24
# Loaded 12 datapoints for 2018-07-24
# 2018-07-25
# Loaded 12 datapoints for 2018-07-25
# 2018-07-26
# Loaded 13 datapoints for 2018-07-26
# 2018-07-27
# Loaded 13 datapoints for 2018-07-27
# 2018-07-28
# Loaded 10 datapoints for 2018-07-28
# 2018-07-29
# Loaded 10 datapoints for 2018-07-29
# 2018-07-30
# Loaded 13 datapoints for 2018-07-30
# 2018-07-31
# Loaded 14 datapoints for 2018-07-31
# 2018-08-01
# Loaded 15 datapoints for 2018-08-01
# 2018-08-02
# Loaded 14 datapoints for 2018-08-02
# 2018-08-03
# Loaded 13 datapoints for 2018-08-03
# 2018-08-04
# Loaded 6 datapoints for 2018-08-04
# 2018-08-05
# Loaded 5 datapoints for 2018-08-05
# 2018-08-06
# Loaded 15 datapoints for 2018-08-06
# 2018-08-07
# Loaded 15 datapoints for 2018-08-07
# 2018-08-08
# Loaded 14 datapoints for 2018-08-08
# 2018-08-09
# Loaded 13 datapoints for 2018-08-09
# 2018-08-10
# Loaded 13 datapoints for 2018-08-10
# 2018-08-11
# hourly not in keys for 2018-08-11
# 2018-08-12
# Loaded 9 datapoints for 2018-08-12
# 2018-08-13
# Loaded 12 datapoints for 2018-08-13
# 2018-08-14
# Loaded 13 datapoints for 2018-08-14
# 2018-08-15
# Loaded 13 datapoints for 2018-08-15
# 2018-08-16
# Loaded 12 datapoints for 2018-08-16
# 2018-08-17
# Loaded 14 datapoints for 2018-08-17
# 2018-08-18
# Loaded 6 datapoints for 2018-08-18
# 2018-08-19
# hourly not in keys for 2018-08-19
# 2018-08-20
# Loaded 11 datapoints for 2018-08-20
# 2018-08-21
# Loaded 17 datapoints for 2018-08-21
# 2018-08-22
# Loaded 16 datapoints for 2018-08-22
# 2018-08-23
# Loaded 15 datapoints for 2018-08-23
# 2018-08-24
# Loaded 13 datapoints for 2018-08-24
# 2018-08-25
# Loaded 4 datapoints for 2018-08-25
# 2018-08-26
# Loaded 2 datapoints for 2018-08-26
# 2018-08-27
# Loaded 13 datapoints for 2018-08-27
# 2018-08-28
# Loaded 14 datapoints for 2018-08-28
# 2018-08-29
# Loaded 13 datapoints for 2018-08-29
# 2018-08-30
# Loaded 13 datapoints for 2018-08-30
# 2018-08-31
# Loaded 13 datapoints for 2018-08-31
# 2018-09-01
# Loaded 8 datapoints for 2018-09-01
# 2018-09-02
# Loaded 8 datapoints for 2018-09-02
# 2018-09-03
# Loaded 12 datapoints for 2018-09-03
# 2018-09-04
# Loaded 13 datapoints for 2018-09-04
# 2018-09-05
# Loaded 13 datapoints for 2018-09-05
# 2018-09-06
# Loaded 13 datapoints for 2018-09-06
# 2018-09-07
# Loaded 13 datapoints for 2018-09-07
# 2018-09-08
# Loaded 2 datapoints for 2018-09-08
# 2018-09-09
# Loaded 2 datapoints for 2018-09-09
# 2018-09-10
# Loaded 14 datapoints for 2018-09-10
# 2018-09-11
# Loaded 14 datapoints for 2018-09-11
# 2018-09-12
# Loaded 13 datapoints for 2018-09-12
# 2018-09-13
# Loaded 14 datapoints for 2018-09-13
# 2018-09-14
# Loaded 13 datapoints for 2018-09-14
# 2018-09-15
# hourly not in keys for 2018-09-15
# 2018-09-16
# Loaded 2 datapoints for 2018-09-16
# 2018-09-17
# Loaded 13 datapoints for 2018-09-17
# 2018-09-18
# Loaded 16 datapoints for 2018-09-18
# 2018-09-19
# Loaded 15 datapoints for 2018-09-19
# 2018-09-20
# Loaded 13 datapoints for 2018-09-20
# 2018-09-21
# Loaded 13 datapoints for 2018-09-21
# 2018-09-22
# Loaded 3 datapoints for 2018-09-22
# 2018-09-23
# Loaded 2 datapoints for 2018-09-23
# 2018-09-24
# Loaded 13 datapoints for 2018-09-24
# 2018-09-25
# Loaded 15 datapoints for 2018-09-25
# 2018-09-26
# Loaded 13 datapoints for 2018-09-26
# 2018-09-27
# Loaded 13 datapoints for 2018-09-27
# 2018-09-28
# Loaded 13 datapoints for 2018-09-28
# 2018-09-29
# Loaded 9 datapoints for 2018-09-29
# 2018-09-30
# Loaded 11 datapoints for 2018-09-30
# 2018-10-01
# Loaded 13 datapoints for 2018-10-01
# 2018-10-02
# Loaded 13 datapoints for 2018-10-02
# 2018-10-03
# Loaded 7 datapoints for 2018-10-03
# 2018-10-04
# Loaded 13 datapoints for 2018-10-04
# 2018-10-05
# Loaded 13 datapoints for 2018-10-05
# 2018-10-06
# Loaded 3 datapoints for 2018-10-06
# 2018-10-07
# Loaded 5 datapoints for 2018-10-07
# 2018-10-08
# Loaded 13 datapoints for 2018-10-08
# 2018-10-09
# Loaded 14 datapoints for 2018-10-09
# 2018-10-10
# Loaded 12 datapoints for 2018-10-10
# 2018-10-11
# Loaded 12 datapoints for 2018-10-11
# 2018-10-12
# Loaded 13 datapoints for 2018-10-12
# 2018-10-13
# hourly not in keys for 2018-10-13
# 2018-10-14
# Loaded 2 datapoints for 2018-10-14
# 2018-10-15
# Loaded 13 datapoints for 2018-10-15
# 2018-10-16
# Loaded 14 datapoints for 2018-10-16
# 2018-10-17
# Loaded 13 datapoints for 2018-10-17
# 2018-10-18
# Loaded 14 datapoints for 2018-10-18
# 2018-10-19
# Loaded 13 datapoints for 2018-10-19
# 2018-10-20
# Loaded 8 datapoints for 2018-10-20
# 2018-10-21
# Loaded 7 datapoints for 2018-10-21
# 2018-10-22
# Loaded 13 datapoints for 2018-10-22
# 2018-10-23
# Loaded 14 datapoints for 2018-10-23
# 2018-10-24
# Loaded 14 datapoints for 2018-10-24
# 2018-10-25
# Loaded 14 datapoints for 2018-10-25
# 2018-10-26
# Loaded 12 datapoints for 2018-10-26
# 2018-10-27
# Loaded 3 datapoints for 2018-10-27
# 2018-10-28
# hourly not in keys for 2018-10-28
# 2018-10-29
# Loaded 12 datapoints for 2018-10-29
# 2018-10-30
# Loaded 9 datapoints for 2018-10-30
# 2018-10-31
# Loaded 13 datapoints for 2018-10-31
# 2018-11-01
# Loaded 7 datapoints for 2018-11-01
# 2018-11-02
# Loaded 13 datapoints for 2018-11-02
# 2018-11-03
# Loaded 5 datapoints for 2018-11-03
# 2018-11-04
# hourly not in keys for 2018-11-04
# 2018-11-05
# Loaded 13 datapoints for 2018-11-05
# 2018-11-06
# Loaded 10 datapoints for 2018-11-06
# 2018-11-07
# Loaded 13 datapoints for 2018-11-07
# 2018-11-08
# Loaded 15 datapoints for 2018-11-08
# 2018-11-09
# Loaded 13 datapoints for 2018-11-09
# 2018-11-10
# hourly not in keys for 2018-11-10
# 2018-11-11
# hourly not in keys for 2018-11-11
# 2018-11-12
# Loaded 13 datapoints for 2018-11-12
# 2018-11-13
# Loaded 10 datapoints for 2018-11-13
# 2018-11-14
# Loaded 13 datapoints for 2018-11-14
# 2018-11-15
# Loaded 13 datapoints for 2018-11-15
# 2018-11-16
# Loaded 13 datapoints for 2018-11-16
# 2018-11-17
# Loaded 9 datapoints for 2018-11-17
# 2018-11-18
# Loaded 7 datapoints for 2018-11-18
# 2018-11-19
# Loaded 13 datapoints for 2018-11-19
# 2018-11-20
# Loaded 16 datapoints for 2018-11-20
# 2018-11-21
# Loaded 14 datapoints for 2018-11-21
# 2018-11-22
# Loaded 13 datapoints for 2018-11-22
# 2018-11-23
# Loaded 13 datapoints for 2018-11-23
# 2018-11-24
# hourly not in keys for 2018-11-24
# 2018-11-25
# Loaded 5 datapoints for 2018-11-25
# 2018-11-26
# Loaded 13 datapoints for 2018-11-26
# 2018-11-27
# Loaded 13 datapoints for 2018-11-27
# 2018-11-28
# Loaded 13 datapoints for 2018-11-28
# 2018-11-29
# Loaded 13 datapoints for 2018-11-29
# 2018-11-30
# Loaded 16 datapoints for 2018-11-30
# 2018-12-01
# Loaded 13 datapoints for 2018-12-01
# 2018-12-02
# Loaded 10 datapoints for 2018-12-02
# 2018-12-03
# Loaded 13 datapoints for 2018-12-03
# 2018-12-04
# Loaded 14 datapoints for 2018-12-04
# 2018-12-05
# Loaded 13 datapoints for 2018-12-05
# 2018-12-06
# Loaded 13 datapoints for 2018-12-06
# 2018-12-07
# Loaded 13 datapoints for 2018-12-07
# 2018-12-08
# Loaded 10 datapoints for 2018-12-08
# 2018-12-09
# Loaded 9 datapoints for 2018-12-09
# 2018-12-10
# Loaded 14 datapoints for 2018-12-10
# 2018-12-11
# Loaded 16 datapoints for 2018-12-11
# 2018-12-12
# Loaded 15 datapoints for 2018-12-12
# 2018-12-13
# Loaded 13 datapoints for 2018-12-13
# 2018-12-14
# Loaded 13 datapoints for 2018-12-14
# 2018-12-15
# Loaded 12 datapoints for 2018-12-15
# 2018-12-16
# Loaded 6 datapoints for 2018-12-16
# 2018-12-17
# Loaded 13 datapoints for 2018-12-17
# 2018-12-18
# Loaded 15 datapoints for 2018-12-18
# 2018-12-19
# Loaded 13 datapoints for 2018-12-19
# 2018-12-20
# Loaded 13 datapoints for 2018-12-20
# 2018-12-21
# Loaded 15 datapoints for 2018-12-21
# 2018-12-22
# Loaded 7 datapoints for 2018-12-22
# 2018-12-23
# hourly not in keys for 2018-12-23
# 2018-12-24
# hourly not in keys for 2018-12-24
# 2018-12-25
# hourly not in keys for 2018-12-25
# 2018-12-26
# hourly not in keys for 2018-12-26
# 2018-12-27
# Loaded 8 datapoints for 2018-12-27
# 2018-12-28
# Loaded 8 datapoints for 2018-12-28
# 2018-12-29
# hourly not in keys for 2018-12-29
# 2018-12-30
# hourly not in keys for 2018-12-30
# 2018-12-31
# hourly not in keys for 2018-12-31
# 2019-01-01
# hourly not in keys for 2019-01-01
# 2019-01-02
# Loaded 8 datapoints for 2019-01-02
# 2019-01-03
# Loaded 8 datapoints for 2019-01-03
# 2019-01-04
# Loaded 8 datapoints for 2019-01-04
# 2019-01-05
# hourly not in keys for 2019-01-05
# 2019-01-06
# hourly not in keys for 2019-01-06
# 2019-01-07
# Loaded 13 datapoints for 2019-01-07
# 2019-01-08
# Loaded 13 datapoints for 2019-01-08
# 2019-01-09
# Loaded 13 datapoints for 2019-01-09
# 2019-01-10
# Loaded 13 datapoints for 2019-01-10
# 2019-01-11
# Loaded 13 datapoints for 2019-01-11
# 2019-01-12
# Loaded 9 datapoints for 2019-01-12
# 2019-01-13
# Loaded 11 datapoints for 2019-01-13
# 2019-01-14
# Loaded 24 datapoints for 2019-01-14
# 2019-01-15
# Loaded 24 datapoints for 2019-01-15
# 2019-01-16
# Loaded 24 datapoints for 2019-01-16
# 2019-01-17
# Loaded 24 datapoints for 2019-01-17
# 2019-01-18
# Loaded 24 datapoints for 2019-01-18
# 2019-01-19
# Loaded 24 datapoints for 2019-01-19
# 2019-01-20
# Loaded 24 datapoints for 2019-01-20
# 2019-01-21
# Loaded 24 datapoints for 2019-01-21
# 2019-01-22
# Loaded 24 datapoints for 2019-01-22
# 2019-01-23
# Loaded 24 datapoints for 2019-01-23
# 2019-01-24
# Loaded 24 datapoints for 2019-01-24
# 2019-01-25
# Loaded 24 datapoints for 2019-01-25
# 2019-01-26
# Loaded 24 datapoints for 2019-01-26
# 2019-01-27
# Loaded 24 datapoints for 2019-01-27
# 2019-01-28
# Loaded 24 datapoints for 2019-01-28
# 2019-01-29
# Loaded 24 datapoints for 2019-01-29
# 2019-01-30
# Loaded 24 datapoints for 2019-01-30
# 2019-01-31
# Loaded 24 datapoints for 2019-01-31
# 2019-02-01
# Loaded 24 datapoints for 2019-02-01
# 2019-02-02
# Loaded 24 datapoints for 2019-02-02
# 2019-02-03
# Loaded 24 datapoints for 2019-02-03
# 2019-02-04
# Loaded 24 datapoints for 2019-02-04
# 2019-02-05
# Loaded 24 datapoints for 2019-02-05
# 2019-02-06
# Loaded 24 datapoints for 2019-02-06
# 2019-02-07
# Loaded 24 datapoints for 2019-02-07
# 2019-02-08
# Loaded 24 datapoints for 2019-02-08
# 2019-02-09
# Loaded 24 datapoints for 2019-02-09
# 2019-02-10
# Loaded 24 datapoints for 2019-02-10
# 2019-02-11
# hourly not in keys for 2019-02-11
# 2019-02-12
# hourly not in keys for 2019-02-12
# 2019-02-13
# hourly not in keys for 2019-02-13
# 2019-02-14
# hourly not in keys for 2019-02-14
# 2019-02-15
# hourly not in keys for 2019-02-15
# 2019-02-16
# hourly not in keys for 2019-02-16
# 2019-02-17
# hourly not in keys for 2019-02-17
# 2019-02-18
# hourly not in keys for 2019-02-18
# 2019-02-19
# hourly not in keys for 2019-02-19
# 2019-02-20
# hourly not in keys for 2019-02-20
# 2019-02-21
# hourly not in keys for 2019-02-21
# 2019-02-22
# hourly not in keys for 2019-02-22
# 2019-02-23
# hourly not in keys for 2019-02-23
# 2019-02-24
# hourly not in keys for 2019-02-24
# 2019-02-25
# hourly not in keys for 2019-02-25
# 2019-02-26
# hourly not in keys for 2019-02-26
# 2019-02-27
# hourly not in keys for 2019-02-27
# 2019-02-28
# hourly not in keys for 2019-02-28
# 2019-03-01
# hourly not in keys for 2019-03-01
# 2019-03-02
# hourly not in keys for 2019-03-02
# 2019-03-03
# hourly not in keys for 2019-03-03
# 2019-03-04
# hourly not in keys for 2019-03-04
# 2019-03-05
# hourly not in keys for 2019-03-05
# 2019-03-06
# hourly not in keys for 2019-03-06
# 2019-03-07
# hourly not in keys for 2019-03-07
# 2019-03-08
# hourly not in keys for 2019-03-08
# 2019-03-09
# hourly not in keys for 2019-03-09
# 2019-03-10
# hourly not in keys for 2019-03-10
# 2019-03-11
# hourly not in keys for 2019-03-11
# 2019-03-12
# hourly not in keys for 2019-03-12
# 2019-03-13
# hourly not in keys for 2019-03-13
# 2019-03-14
# hourly not in keys for 2019-03-14
# 2019-03-15
# hourly not in keys for 2019-03-15
# 2019-03-16
# hourly not in keys for 2019-03-16
# 2019-03-17
# hourly not in keys for 2019-03-17
# 2019-03-18
# hourly not in keys for 2019-03-18
# 2019-03-19
# hourly not in keys for 2019-03-19
# 2019-03-20
# hourly not in keys for 2019-03-20
# 2019-03-21
# hourly not in keys for 2019-03-21
# 2019-03-22
# hourly not in keys for 2019-03-22
# 2019-03-23
# hourly not in keys for 2019-03-23
# 2019-03-24
# hourly not in keys for 2019-03-24
# 2019-03-25
# hourly not in keys for 2019-03-25
# 2019-03-26
# hourly not in keys for 2019-03-26
# 2019-03-27
# hourly not in keys for 2019-03-27
# 2019-03-28
# hourly not in keys for 2019-03-28
# 2019-03-29
# hourly not in keys for 2019-03-29
# 2019-03-30
# hourly not in keys for 2019-03-30
# 2019-03-31
# hourly not in keys for 2019-03-31
# 2019-04-01
# hourly not in keys for 2019-04-01
# 2019-04-02
# hourly not in keys for 2019-04-02
# 2019-04-03
# hourly not in keys for 2019-04-03
# 2019-04-04
# hourly not in keys for 2019-04-04
# 2019-04-05
# hourly not in keys for 2019-04-05
# 2019-04-06
# hourly not in keys for 2019-04-06
# 2019-04-07
# hourly not in keys for 2019-04-07
# 2019-04-08
# hourly not in keys for 2019-04-08
# 2019-04-09
# hourly not in keys for 2019-04-09
# 2019-04-10
# hourly not in keys for 2019-04-10
# 2019-04-11
# hourly not in keys for 2019-04-11
# 2019-04-12
# hourly not in keys for 2019-04-12
# 2019-04-13
# hourly not in keys for 2019-04-13
# 2019-04-14
# hourly not in keys for 2019-04-14
# 2019-04-15
# hourly not in keys for 2019-04-15
# 2019-04-16
# hourly not in keys for 2019-04-16
# 2019-04-17
# hourly not in keys for 2019-04-17
# 2019-04-18
# hourly not in keys for 2019-04-18
# 2019-04-19
# hourly not in keys for 2019-04-19
# 2019-04-20
# hourly not in keys for 2019-04-20
# 2019-04-21
# hourly not in keys for 2019-04-21
# 2019-04-22
# hourly not in keys for 2019-04-22
# 2019-04-23
# hourly not in keys for 2019-04-23
# 2019-04-24
# hourly not in keys for 2019-04-24
# 2019-04-25
# hourly not in keys for 2019-04-25
# 2019-04-26
# hourly not in keys for 2019-04-26
# 2019-04-27
# hourly not in keys for 2019-04-27
# 2019-04-28
# hourly not in keys for 2019-04-28
# 2019-04-29
# hourly not in keys for 2019-04-29
# 2019-04-30
# hourly not in keys for 2019-04-30
# 2019-05-01
# hourly not in keys for 2019-05-01
# 2019-05-02
# hourly not in keys for 2019-05-02
# 2019-05-03
# hourly not in keys for 2019-05-03
# 2019-05-04
# hourly not in keys for 2019-05-04
# 2019-05-05
# hourly not in keys for 2019-05-05
# 2019-05-06
# hourly not in keys for 2019-05-06
# 2019-05-07
# hourly not in keys for 2019-05-07
# 2019-05-08
# hourly not in keys for 2019-05-08
# 2019-05-09
# hourly not in keys for 2019-05-09
# 2019-05-10
# hourly not in keys for 2019-05-10
# 2019-05-11
# hourly not in keys for 2019-05-11
# 2019-05-12
# hourly not in keys for 2019-05-12
# 2019-05-13
# hourly not in keys for 2019-05-13
# 2019-05-14
# hourly not in keys for 2019-05-14
# 2019-05-15
# hourly not in keys for 2019-05-15
# 2019-05-16
# hourly not in keys for 2019-05-16
# 2019-05-17
# hourly not in keys for 2019-05-17
# 2019-05-18
# hourly not in keys for 2019-05-18
# 2019-05-19
# hourly not in keys for 2019-05-19
# 2019-05-20
# hourly not in keys for 2019-05-20
# 2019-05-21
# hourly not in keys for 2019-05-21
# 2019-05-22
# hourly not in keys for 2019-05-22
# 2019-05-23
# hourly not in keys for 2019-05-23
# 2019-05-24
# hourly not in keys for 2019-05-24
# 2019-05-25
# hourly not in keys for 2019-05-25
# 2019-05-26
# hourly not in keys for 2019-05-26
# 2019-05-27
# hourly not in keys for 2019-05-27
# 2019-05-28
# hourly not in keys for 2019-05-28
# 2019-05-29
# hourly not in keys for 2019-05-29
# 2019-05-30
# hourly not in keys for 2019-05-30
# 2019-05-31
# hourly not in keys for 2019-05-31
# 2019-06-01
# hourly not in keys for 2019-06-01
# 2019-06-02
# hourly not in keys for 2019-06-02
# 2019-06-03
# hourly not in keys for 2019-06-03
# 2019-06-04
# hourly not in keys for 2019-06-04
# 2019-06-05
# hourly not in keys for 2019-06-05
# 2019-06-06
# hourly not in keys for 2019-06-06
# 2019-06-07
# hourly not in keys for 2019-06-07
# 2019-06-08
# hourly not in keys for 2019-06-08
# 2019-06-09
# hourly not in keys for 2019-06-09
# 2019-06-10
# hourly not in keys for 2019-06-10
# 2019-06-11
# hourly not in keys for 2019-06-11
# 2019-06-12
# hourly not in keys for 2019-06-12
# 2019-06-13
# hourly not in keys for 2019-06-13
# 2019-06-14
# hourly not in keys for 2019-06-14
# 2019-06-15
# hourly not in keys for 2019-06-15
# 2019-06-16
# hourly not in keys for 2019-06-16
# 2019-06-17
# hourly not in keys for 2019-06-17
# 2019-06-18
# hourly not in keys for 2019-06-18
# 2019-06-19
# hourly not in keys for 2019-06-19
# 2019-06-20
# hourly not in keys for 2019-06-20
# 2019-06-21
# hourly not in keys for 2019-06-21
# 2019-06-22
# hourly not in keys for 2019-06-22
# 2019-06-23
# hourly not in keys for 2019-06-23
# 2019-06-24
# hourly not in keys for 2019-06-24
# 2019-06-25
# hourly not in keys for 2019-06-25
# 2019-06-26
# hourly not in keys for 2019-06-26
# 2019-06-27
# hourly not in keys for 2019-06-27
# 2019-06-28
# hourly not in keys for 2019-06-28
# 2019-06-29
# hourly not in keys for 2019-06-29
# 2019-06-30
# hourly not in keys for 2019-06-30
# 2019-07-01
# hourly not in keys for 2019-07-01
# 2019-07-02
# hourly not in keys for 2019-07-02
# 2019-07-03
# hourly not in keys for 2019-07-03
# 2019-07-04
# hourly not in keys for 2019-07-04
# 2019-07-05
# hourly not in keys for 2019-07-05
# 2019-07-06
# hourly not in keys for 2019-07-06
# 2019-07-07
# hourly not in keys for 2019-07-07
# 2019-07-08
# hourly not in keys for 2019-07-08
# 2019-07-09
# hourly not in keys for 2019-07-09
# 2019-07-10
# hourly not in keys for 2019-07-10
# 2019-07-11
# hourly not in keys for 2019-07-11
# 2019-07-12
# hourly not in keys for 2019-07-12
# 2019-07-13
# hourly not in keys for 2019-07-13
# 2019-07-14
# hourly not in keys for 2019-07-14
# 2019-07-15
# hourly not in keys for 2019-07-15
# 2019-07-16
# hourly not in keys for 2019-07-16
# 2019-07-17
# hourly not in keys for 2019-07-17
# 2019-07-18
# hourly not in keys for 2019-07-18
# 2019-07-19
# hourly not in keys for 2019-07-19
# 2019-07-20
# hourly not in keys for 2019-07-20
# 2019-07-21
# hourly not in keys for 2019-07-21
# 2019-07-22
# hourly not in keys for 2019-07-22
# 2019-07-23
# hourly not in keys for 2019-07-23
# 2019-07-24
# hourly not in keys for 2019-07-24
# 2019-07-25
# hourly not in keys for 2019-07-25
# 2019-07-26
# hourly not in keys for 2019-07-26
# 2019-07-27
# hourly not in keys for 2019-07-27
# 2019-07-28
# hourly not in keys for 2019-07-28
# 2019-07-29
# hourly not in keys for 2019-07-29
# 2019-07-30
# hourly not in keys for 2019-07-30
# 2019-07-31
# hourly not in keys for 2019-07-31
# 2019-08-01
# hourly not in keys for 2019-08-01
# 2019-08-02
# hourly not in keys for 2019-08-02
# 2019-08-03
# hourly not in keys for 2019-08-03
# 2019-08-04
# hourly not in keys for 2019-08-04
# 2019-08-05
# hourly not in keys for 2019-08-05
# 2019-08-06
# hourly not in keys for 2019-08-06
# 2019-08-07
# hourly not in keys for 2019-08-07
# 2019-08-08
# hourly not in keys for 2019-08-08
# 2019-08-09
# hourly not in keys for 2019-08-09
# 2019-08-10
# hourly not in keys for 2019-08-10
# 2019-08-11
# hourly not in keys for 2019-08-11
# 2019-08-12
# hourly not in keys for 2019-08-12
# 2019-08-13
# hourly not in keys for 2019-08-13
# 2019-08-14
# hourly not in keys for 2019-08-14
# 2019-08-15
# hourly not in keys for 2019-08-15
# 2019-08-16
# hourly not in keys for 2019-08-16
# 2019-08-17
# hourly not in keys for 2019-08-17
# 2019-08-18
# hourly not in keys for 2019-08-18
# 2019-08-19
# hourly not in keys for 2019-08-19
# 2019-08-20
# hourly not in keys for 2019-08-20
# 2019-08-21
# hourly not in keys for 2019-08-21
# 2019-08-22
# hourly not in keys for 2019-08-22
# 2019-08-23
# hourly not in keys for 2019-08-23
# 2019-08-24
# hourly not in keys for 2019-08-24
# 2019-08-25
# hourly not in keys for 2019-08-25
# 2019-08-26
# hourly not in keys for 2019-08-26
# 2019-08-27
# hourly not in keys for 2019-08-27
# 2019-08-28
# hourly not in keys for 2019-08-28
# 2019-08-29
# hourly not in keys for 2019-08-29
# 2019-08-30
# hourly not in keys for 2019-08-30
# 2019-08-31
# hourly not in keys for 2019-08-31
# 2019-09-01
# hourly not in keys for 2019-09-01
# 2019-09-02
# hourly not in keys for 2019-09-02
# 2019-09-03
# hourly not in keys for 2019-09-03
# 2019-09-04
# hourly not in keys for 2019-09-04
# 2019-09-05
# hourly not in keys for 2019-09-05
# 2019-09-06
# hourly not in keys for 2019-09-06
# 2019-09-07
# hourly not in keys for 2019-09-07
# 2019-09-08
# hourly not in keys for 2019-09-08
# 2019-09-09
# hourly not in keys for 2019-09-09
# 2019-09-10
# hourly not in keys for 2019-09-10
# 2019-09-11
# hourly not in keys for 2019-09-11
# 2019-09-12
# hourly not in keys for 2019-09-12
# 2019-09-13
# hourly not in keys for 2019-09-13
# 2019-09-14
# hourly not in keys for 2019-09-14
# 2019-09-15
# hourly not in keys for 2019-09-15
# 2019-09-16
# hourly not in keys for 2019-09-16
# 2019-09-17
# hourly not in keys for 2019-09-17
# 2019-09-18
# hourly not in keys for 2019-09-18
# 2019-09-19
# hourly not in keys for 2019-09-19
# 2019-09-20
# hourly not in keys for 2019-09-20
# 2019-09-21
# hourly not in keys for 2019-09-21
# 2019-09-22
# hourly not in keys for 2019-09-22
# 2019-09-23
# hourly not in keys for 2019-09-23
# 2019-09-24
# hourly not in keys for 2019-09-24
# 2019-09-25
# hourly not in keys for 2019-09-25
# 2019-09-26
# hourly not in keys for 2019-09-26
# 2019-09-27
# hourly not in keys for 2019-09-27
# 2019-09-28
# hourly not in keys for 2019-09-28
# 2019-09-29
# hourly not in keys for 2019-09-29
# 2019-09-30
# hourly not in keys for 2019-09-30
# 2019-10-01
# hourly not in keys for 2019-10-01
# 2019-10-02
# hourly not in keys for 2019-10-02
# 2019-10-03
# hourly not in keys for 2019-10-03
# 2019-10-04
# hourly not in keys for 2019-10-04
# 2019-10-05
# hourly not in keys for 2019-10-05
# 2019-10-06
# hourly not in keys for 2019-10-06
# 2019-10-07
# hourly not in keys for 2019-10-07
# 2019-10-08
# hourly not in keys for 2019-10-08
# 2019-10-09
# hourly not in keys for 2019-10-09
# 2019-10-10
# hourly not in keys for 2019-10-10
# 2019-10-11
# hourly not in keys for 2019-10-11
# 2019-10-12
# hourly not in keys for 2019-10-12
# 2019-10-13
# hourly not in keys for 2019-10-13
# 2019-10-14
# hourly not in keys for 2019-10-14
# 2019-10-15
# hourly not in keys for 2019-10-15
# 2019-10-16
# hourly not in keys for 2019-10-16
# 2019-10-17
# hourly not in keys for 2019-10-17
# 2019-10-18
# hourly not in keys for 2019-10-18
# 2019-10-19
# hourly not in keys for 2019-10-19
# 2019-10-20
# hourly not in keys for 2019-10-20
# 2019-10-21
# hourly not in keys for 2019-10-21
# 2019-10-22
# hourly not in keys for 2019-10-22
# 2019-10-23
# hourly not in keys for 2019-10-23
# 2019-10-24
# hourly not in keys for 2019-10-24
# 2019-10-25
# hourly not in keys for 2019-10-25
# 2019-10-26
# hourly not in keys for 2019-10-26
# 2019-10-27
# hourly not in keys for 2019-10-27
# 2019-10-28
# hourly not in keys for 2019-10-28
# 2019-10-29
# hourly not in keys for 2019-10-29
# 2019-10-30
# hourly not in keys for 2019-10-30
# 2019-10-31
# hourly not in keys for 2019-10-31
# 2019-11-01
# hourly not in keys for 2019-11-01
# 2019-11-02
# hourly not in keys for 2019-11-02
# 2019-11-03
# hourly not in keys for 2019-11-03
# 2019-11-04
# hourly not in keys for 2019-11-04
# 2019-11-05
# hourly not in keys for 2019-11-05
# 2019-11-06
# hourly not in keys for 2019-11-06
# 2019-11-07
# hourly not in keys for 2019-11-07
# 2019-11-08
# hourly not in keys for 2019-11-08
# 2019-11-09
# hourly not in keys for 2019-11-09
# 2019-11-10
# hourly not in keys for 2019-11-10
# 2019-11-11
# hourly not in keys for 2019-11-11
# 2019-11-12
# hourly not in keys for 2019-11-12
# 2019-11-13
# hourly not in keys for 2019-11-13
# 2019-11-14
# hourly not in keys for 2019-11-14
# 2019-11-15
# hourly not in keys for 2019-11-15
# 2019-11-16
# hourly not in keys for 2019-11-16
# 2019-11-17
# hourly not in keys for 2019-11-17
# 2019-11-18
# hourly not in keys for 2019-11-18
# 2019-11-19
# hourly not in keys for 2019-11-19
# 2019-11-20
# hourly not in keys for 2019-11-20
# 2019-11-21
# hourly not in keys for 2019-11-21
# 2019-11-22
# hourly not in keys for 2019-11-22
# 2019-11-23
# hourly not in keys for 2019-11-23
# 2019-11-24
# hourly not in keys for 2019-11-24
# 2019-11-25
# hourly not in keys for 2019-11-25
# 2019-11-26
# hourly not in keys for 2019-11-26
# 2019-11-27
# hourly not in keys for 2019-11-27
# 2019-11-28
# hourly not in keys for 2019-11-28
# 2019-11-29
# hourly not in keys for 2019-11-29
# 2019-11-30
# hourly not in keys for 2019-11-30
# 2019-12-01
# hourly not in keys for 2019-12-01
# 2019-12-02
# hourly not in keys for 2019-12-02
# 2019-12-03
# hourly not in keys for 2019-12-03
# 2019-12-04
# hourly not in keys for 2019-12-04
# 2019-12-05
# hourly not in keys for 2019-12-05
# 2019-12-06
# hourly not in keys for 2019-12-06
# 2019-12-07
# hourly not in keys for 2019-12-07
# 2019-12-08
# hourly not in keys for 2019-12-08
# 2019-12-09
# hourly not in keys for 2019-12-09
# 2019-12-10
# hourly not in keys for 2019-12-10
# 2019-12-11
# hourly not in keys for 2019-12-11
# 2019-12-12
# hourly not in keys for 2019-12-12
# 2019-12-13
# hourly not in keys for 2019-12-13
# 2019-12-14
# hourly not in keys for 2019-12-14
# 2019-12-15
# hourly not in keys for 2019-12-15
# 2019-12-16
# hourly not in keys for 2019-12-16
# 2019-12-17
# hourly not in keys for 2019-12-17
# 2019-12-18
# hourly not in keys for 2019-12-18
# 2019-12-19
# hourly not in keys for 2019-12-19
# 2019-12-20
# hourly not in keys for 2019-12-20
# 2019-12-21
# hourly not in keys for 2019-12-21
# 2019-12-22
# hourly not in keys for 2019-12-22
# 2019-12-23
# hourly not in keys for 2019-12-23
# 2019-12-24
# hourly not in keys for 2019-12-24
# 2019-12-25
# hourly not in keys for 2019-12-25
# 2019-12-26
# hourly not in keys for 2019-12-26
# 2019-12-27
# hourly not in keys for 2019-12-27
# 2019-12-28
# hourly not in keys for 2019-12-28
# 2019-12-29
# hourly not in keys for 2019-12-29
# 2019-12-30
# hourly not in keys for 2019-12-30
# 2019-12-31
# hourly not in keys for 2019-12-31
# 2020-01-01
# hourly not in keys for 2020-01-01
# 2020-01-02
# hourly not in keys for 2020-01-02
# 2020-01-03
# hourly not in keys for 2020-01-03
# 2020-01-04
# hourly not in keys for 2020-01-04
# 2020-01-05
# hourly not in keys for 2020-01-05
# 2020-01-06
# hourly not in keys for 2020-01-06
# 2020-01-07
# hourly not in keys for 2020-01-07
# 2020-01-08
# hourly not in keys for 2020-01-08
# 2020-01-09
# hourly not in keys for 2020-01-09
# 2020-01-10
# hourly not in keys for 2020-01-10
# 2020-01-11
# hourly not in keys for 2020-01-11
# 2020-01-12
# hourly not in keys for 2020-01-12
# 2020-01-13
# hourly not in keys for 2020-01-13

# %%
class DarkSkyETL():
    
    def __init__(self, DarkSkyAPI, location, save_path):
        self.API = DarkSkyAPI
        self.LOCATION = location
        self.SAVE_PATH = save_path # where to store output json files. will be stored as save_pathYYYY-MM-DD.json
        
    def call_API(self, date_str, silent=False):
        """
        Calls the DarkSky API for the specified location at the specified date, which must be a string in the
        format YYYY-00-DD. Asks for hourly data and returns a json object for this date.
        Prints the number of hours loaded if silent is True.
        """
        # option list for API
        option_list = "exclude=currently,minutely,alerts&units=si"
        
        # convert to a timestamp at mid-day
        date = datetime.datetime.strptime(date_str, '%Y-%m-%d') + pd.DateOffset(hours=12)
        
        # convert the date to unit time
        unix_time = int(datetime.datetime.timestamp(date))
        
        # call API
        latitude = LOCATION[0]
        longitude = LOCATION[1]
        response = requests.get("https://api.darksky.net/forecast/"+DarkSkyAPI+"/"+latitude+","+longitude+","+str(unix_time)+"?"+option_list)
        json_res = response.json()

        # write to file
        with open(f'{self.SAVE_PATH}/{date_str}.json', 'w') as outfile:  
            json.dump(json_res, outfile)
            outfile.close()

        if silent == False:
            # some dates have no data
            if 'hourly' in json_res.keys():
                datapoints = len(json_res['hourly']['data'])
                print(f"Loaded {datapoints} datapoints for {date_str}")
            else:
                print(f"hourly not in keys for {date_str}")
            
        return json_res
    
    def get_date_range(self, start_date, end_date, silent=False):
        """
        Gets a list of dates in steps of one day between start_date and end_date. Calls the API and saves the json return file at the location save_path.
        INPUT:
            - start_date: STRING, date to start
            - end_date: STRING, date to end the list
            - silent: BOOLEAN, False, if the number of datapoints on each date should be printed out
        OUTPUT:
            None
        """
        
        # convert to a time delta
        d_from_date = datetime.datetime.strptime(start_date, '%Y-%m-%d')
        d_to_date = datetime.datetime.strptime(end_date, '%Y-%m-%d')
        delta = d_to_date - d_from_date
        
        # for every day in the date range, get the data
        for i in range(delta.days+1):
            date = str((d_from_date + datetime.timedelta(days=i)).date())
            print(date)
            self.call_API(date, silent)
